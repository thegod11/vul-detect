# %% [markdown]
# # Training a GNN for Graph Classification
#
# By the end of this tutorial, you will be able to
#
# -  Load a DGL-provided graph classification dataset.
# -  Understand what *readout* function does.
# -  Understand how to create and use a minibatch of graphs.
# -  Build a GNN-based graph classification model.
# -  Train and evaluate the model on a DGL-provided dataset.
#
# (Time estimate: 18 minutes)

# %%
import os

os.environ["DGLBACKEND"] = "pytorch"
import dgl
import dgl.data
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ## Overview of Graph Classification with GNN
#
# Graph classification or regression requires a model to predict certain
# graph-level properties of a single graph given its node and edge
# features.  Molecular property prediction is one particular application.
#
# This tutorial shows how to train a graph classification model for a
# small dataset from the paper [How Powerful Are Graph Neural
# Networks](https://arxiv.org/abs/1810.00826)_.
#
# ## Loading Data

# %%
# Generate a synthetic dataset with 10000 graphs, ranging from 10 to 500 nodes.
# !source /etc/network_turbo
dataset = dgl.data.GINDataset("PROTEINS", self_loop=True)
# Out:
# 设置成功
# 注意：仅限于学术用途，不承诺稳定性保证
# Downloading /root/.dgl/GINDataset.zip from https://raw.githubusercontent.com/weihua916/powerful-gnns/master/dataset.zip...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Generate a synthetic dataset with 10000 graphs, ranging from 10 to 500 nodes.
#       2 get_ipython().system('source /etc/network_turbo')
# ----> 3 dataset = dgl.data.GINDataset("PROTEINS", self_loop=True)
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/data/gindt.py:132, in GINDataset.__init__(self, name, self_loop, degree_as_nlabel, raw_dir, force_reload, verbose, transform)
#     129 self.nattrs_flag = False
#     130 self.nlabels_flag = False
# --> 132 super(GINDataset, self).__init__(
#     133     name=name,
#     134     url=gin_url,
#     135     hash_key=(name, self_loop, degree_as_nlabel),
#     136     raw_dir=raw_dir,
#     137     force_reload=force_reload,
#     138     verbose=verbose,
#     139     transform=transform,
#     140 )
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/data/dgl_dataset.py:333, in DGLBuiltinDataset.__init__(self, name, url, raw_dir, hash_key, force_reload, verbose, transform)
#     323 def __init__(
#     324     self,
#     325     name,
#    (...)
#     331     transform=None,
#     332 ):
# --> 333     super(DGLBuiltinDataset, self).__init__(
#     334         name,
#     335         url=url,
#     336         raw_dir=raw_dir,
#     337         save_dir=None,
#     338         hash_key=hash_key,
#     339         force_reload=force_reload,
#     340         verbose=verbose,
#     341         transform=transform,
#     342     )
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/data/dgl_dataset.py:112, in DGLDataset.__init__(self, name, url, raw_dir, save_dir, hash_key, force_reload, verbose, transform)
#     109 else:
#     110     self._save_dir = save_dir
# --> 112 self._load()
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/data/dgl_dataset.py:203, in DGLDataset._load(self)
#     201 if not load_flag:
#     202     self._download()
# --> 203     self.process()
#     204     self.save()
#     205     if self.verbose:
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/data/gindt.py:240, in GINDataset.process(self)
#     237 nlabels.append(self.nlabel_dict[nrow[0]])
#     239 m_edges += nrow[1]
# --> 240 g.add_edges(j, nrow[2:])
#     242 # add self loop
#     243 if self.self_loop:
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/heterograph.py:597, in DGLGraph.add_edges(self, u, v, data, etype)
#     594 for c_etype in self.canonical_etypes:
#     595     # the target edge type
#     596     if c_etype == (u_type, e_type, v_type):
# --> 597         old_u, old_v = self.edges(form="uv", order="eid", etype=c_etype)
#     598         hgidx = heterograph_index.create_unitgraph_from_coo(
#     599             1 if u_type == v_type else 2,
#     600             self.num_nodes(u_type),
#    (...)
#     604             ["coo", "csr", "csc"],
#     605         )
#     606         relation_graphs.append(hgidx)
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/view.py:179, in HeteroEdgeView.__call__(self, *args, **kwargs)
#     177 def __call__(self, *args, **kwargs):
#     178     """Return all the edges."""
# --> 179     return self._graph.all_edges(*args, **kwargs)
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/heterograph.py:3591, in DGLGraph.all_edges(self, form, order, etype)
#    3521 def all_edges(self, form="uv", order="eid", etype=None):
#    3522     """Return all edges with the specified edge type.
#    3523
#    3524     Parameters
#    (...)
#    3589     out_edges
#    3590     """
# -> 3591     src, dst, eid = self._graph.edges(self.get_etype_id(etype), order)
#    3592     if form == "all":
#    3593         return src, dst, eid
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/heterograph_index.py:699, in HeteroGraphIndex.edges(self, etype, order)
#     697 src = F.from_dgl_nd(edge_array(0))
#     698 dst = F.from_dgl_nd(edge_array(1))
# --> 699 eid = F.from_dgl_nd(edge_array(2))
#     700 return src, dst, eid
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/backend/__init__.py:146, in from_dgl_nd(data)
#     145 def from_dgl_nd(data):
# --> 146     return zerocopy_from_dgl_ndarray(data)
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/backend/pytorch/tensor.py:473, in zerocopy_from_dgl_ndarray(data)
#     466 if data.shape == (0,):
#     467     # NOTE: PyTorch v1.5 does not accept DLPack object representing empty CUDA tensor.
#     468     #  Related issue: https://github.com/pytorch/pytorch/issues/41182
#     469     #  The issue will be fixed in v1.6 and later.
#     470     return th.tensor(
#     471         [], dtype=getattr(th, data.dtype), device=to_backend_ctx(data.ctx)
#     472     )
# --> 473 elif len(data.shape) == 0 or builtins.min(data.shape) == 0:
#     474     # Workaround the same issue as above, but preserve the shape of the
#     475     # empty tensor. This is needed by the sparse optimizer when one of
#     476     # processors may receive no gradients to update, but we want to keep
#     477     # the dimension of the embedding.
#     478     return th.empty(
#     479         data.shape,
#     480         dtype=getattr(th, data.dtype),
#     481         device=to_backend_ctx(data.ctx),
#     482     )
#     483 else:
#
# File ~/miniconda3/envs/vul-detect/lib/python3.9/site-packages/dgl/_ffi/ndarray.py:209, in NDArrayBase.shape(self)
#     206 @property
#     207 def shape(self):
#     208     """Shape of this array"""
# --> 209     return tuple(
#     210         self.handle.contents.shape[i]
#     211         for i in range(self.handle.contents.ndim)
#     212     )
#
# KeyboardInterrupt:

# %% [markdown]
# The dataset is a set of graphs, each with node features and a single
# label. One can see the node feature dimensionality and the number of
# possible graph categories of ``GINDataset`` objects in ``dim_nfeats``
# and ``gclasses`` attributes.

# %%
print("Node feature dimensionality:", dataset.dim_nfeats)
print("Number of graph categories:", dataset.gclasses)


from dgl.dataloading import GraphDataLoader

# %% [markdown]
# ## Defining Data Loader
#
# A graph classification dataset usually contains two types of elements: a
# set of graphs, and their graph-level labels. Similar to an image
# classification task, when the dataset is large enough, we need to train
# with mini-batches. When you train a model for image classification or
# language modeling, you will use a ``DataLoader`` to iterate over the
# dataset. In DGL, you can use the ``GraphDataLoader``.
#
# You can also use various dataset samplers provided in
# [torch.utils.data.sampler](https://pytorch.org/docs/stable/data.html#data-loading-order-and-sampler)_.
# For example, this tutorial creates a training ``GraphDataLoader`` and
# test ``GraphDataLoader``, using ``SubsetRandomSampler`` to tell PyTorch
# to sample from only a subset of the dataset.

# %%
from torch.utils.data.sampler import SubsetRandomSampler

num_examples = len(dataset)
num_train = int(num_examples * 0.8)

train_sampler = SubsetRandomSampler(torch.arange(num_train))
test_sampler = SubsetRandomSampler(torch.arange(num_train, num_examples))

train_dataloader = GraphDataLoader(
    dataset, sampler=train_sampler, batch_size=5, drop_last=False
)
test_dataloader = GraphDataLoader(
    dataset, sampler=test_sampler, batch_size=5, drop_last=False
)

# %% [markdown]
# You can try to iterate over the created ``GraphDataLoader`` and see what it
# gives:

# %%
it = iter(train_dataloader)
batch = next(it)
print(batch)

# %% [markdown]
# As each element in ``dataset`` has a graph and a label, the
# ``GraphDataLoader`` will return two objects for each iteration. The
# first element is the batched graph, and the second element is simply a
# label vector representing the category of each graph in the mini-batch.
# Next, we’ll talked about the batched graph.
#
# ## A Batched Graph in DGL
#
# In each mini-batch, the sampled graphs are combined into a single bigger
# batched graph via ``dgl.batch``. The single bigger batched graph merges
# all original graphs as separately connected components, with the node
# and edge features concatenated. This bigger graph is also a ``DGLGraph``
# instance (so you can
# still treat it as a normal ``DGLGraph`` object as in
# [here](2_dglgraph.ipynb)_). It however contains the information
# necessary for recovering the original graphs, such as the number of
# nodes and edges of each graph element.

# %%
batched_graph, labels = batch
print(
    "Number of nodes for each graph element in the batch:",
    batched_graph.batch_num_nodes(),
)
print(
    "Number of edges for each graph element in the batch:",
    batched_graph.batch_num_edges(),
)

# Recover the original graph elements from the minibatch
graphs = dgl.unbatch(batched_graph)
print("The original graphs in the minibatch:")
print(graphs)

# %% [markdown]
# ## Define Model
#
# This tutorial will build a two-layer [Graph Convolutional Network
# (GCN)](http://tkipf.github.io/graph-convolutional-networks/)_. Each of
# its layer computes new node representations by aggregating neighbor
# information. If you have gone through the
# :doc:`introduction <1_introduction>`, you will notice two
# differences:
#
# -  Since the task is to predict a single category for the *entire graph*
#    instead of for every node, you will need to aggregate the
#    representations of all the nodes and potentially the edges to form a
#    graph-level representation. Such process is more commonly referred as
#    a *readout*. A simple choice is to average the node features of a
#    graph with ``dgl.mean_nodes()``.
#
# -  The input graph to the model will be a batched graph yielded by the
#    ``GraphDataLoader``. The readout functions provided by DGL can handle
#    batched graphs so that they will return one representation for each
#    minibatch element.

# %%
from dgl.nn import GraphConv


class GCN(nn.Module):
    def __init__(self, in_feats, h_feats, num_classes):
        super(GCN, self).__init__()
        self.conv1 = GraphConv(in_feats, h_feats)
        self.conv2 = GraphConv(h_feats, num_classes)

    def forward(self, g, in_feat):
        h = self.conv1(g, in_feat)
        h = F.relu(h)
        h = self.conv2(g, h)
        g.ndata["h"] = h
        return dgl.mean_nodes(g, "h")

# %% [markdown]
# ## Training Loop
#
# The training loop iterates over the training set with the
# ``GraphDataLoader`` object and computes the gradients, just like
# image classification or language modeling.

# %%
# Create the model with given dimensions
model = GCN(dataset.dim_nfeats, 16, dataset.gclasses)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

for epoch in range(20):
    for batched_graph, labels in train_dataloader:
        pred = model(batched_graph, batched_graph.ndata["attr"].float())
        loss = F.cross_entropy(pred, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

num_correct = 0
num_tests = 0
for batched_graph, labels in test_dataloader:
    pred = model(batched_graph, batched_graph.ndata["attr"].float())
    num_correct += (pred.argmax(1) == labels).sum().item()
    num_tests += len(labels)

print("Test accuracy:", num_correct / num_tests)

# %% [markdown]
# ## What’s next
#
# -  See [GIN
#    example](https://github.com/dmlc/dgl/tree/master/examples/pytorch/gin)_
#    for an end-to-end graph classification model.

# %%
# Thumbnail credits: DGL
# sphinx_gallery_thumbnail_path = '_static/blitz_5_graph_classification.png'
